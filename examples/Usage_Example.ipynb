# %% [markdown]
# # Usage Example
#
# In this notebook we will show the most basic usage of **TGAN** in order to generate samples from a
# given dataset.

# %% [markdown]
# ### 1. Load the data
#
# The first step is to load the data wich we will use to fit TGAN. In order to do so, we will first
# import the function `tgan.data.load_data` and call it with the name the dataset that we want to load.
#
# In this case, we will load the `census` dataset, which we will use during the subsequent steps, and obtain two objects:
#
# 1. `data` will contain a `pandas.DataFrame` with the table of data from the `census` dataset ready to be used to fit the model.
#
# 2. `continous_columns` will contain a `list` with the indices of continuous columns.

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']
get_available_gpus()

# %%
from tgan.data import load_demo_data

data, continuous_columns = load_demo_data('census')

data.head(3).T
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1028 18:26:06.764306 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/hooks.py:17: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W1028 18:26:06.778691 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/optimizer.py:18: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1028 18:26:06.780025 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:20: The name tf.train.SessionCreator is deprecated. Please use tf.compat.v1.train.SessionCreator instead.
#                                             0  \
# 0                                          73
# 1                             Not in universe
# 2                                           0
# 3                                           0
# 4                        High school graduate
# 5                                           0
# 6                             Not in universe
# 7                                     Widowed
# 8                 Not in universe or children
# 9                             Not in universe
# 10                                      White
# 11                                  All other
# 12                                     Female
# 13                            Not in universe
# 14                            Not in universe
# 15                         Not in labor force
# 16                                          0
# 17                                          0
# 18                                          0
# 19                                   Nonfiler
# 20                            Not in universe
# 21                            Not in universe
# 22   Other Rel 18+ ever marr not in subfamily
# 23              Other relative of householder
# 24                                          ?
# 25                                          ?
# 26                                          ?
# 27           Not in universe under 1 year old
# 28                                          ?
# 29                                          0
# 30                            Not in universe
# 31                              United-States
# 32                              United-States
# 33                              United-States
# 34          Native- Born in the United States
# 35                                          0
# 36                            Not in universe
# 37                                          2
# 38                                          0
# 39                                         95
# 40                                     -50000
#
#                                        1  \
# 0                                     58
# 1         Self-employed-not incorporated
# 2                                      4
# 3                                     34
# 4             Some college but no degree
# 5                                      0
# 6                        Not in universe
# 7                               Divorced
# 8                           Construction
# 9    Precision production craft & repair
# 10                                 White
# 11                             All other
# 12                                  Male
# 13                       Not in universe
# 14                       Not in universe
# 15              Children or Armed Forces
# 16                                     0
# 17                                     0
# 18                                     0
# 19                     Head of household
# 20                                 South
# 21                              Arkansas
# 22                           Householder
# 23                           Householder
# 24                            MSA to MSA
# 25                           Same county
# 26                           Same county
# 27                                    No
# 28                                   Yes
# 29                                     1
# 30                       Not in universe
# 31                         United-States
# 32                         United-States
# 33                         United-States
# 34     Native- Born in the United States
# 35                                     0
# 36                       Not in universe
# 37                                     2
# 38                                    52
# 39                                    94
# 40                                -50000
#
#                                            2
# 0                                         18
# 1                            Not in universe
# 2                                          0
# 3                                          0
# 4                                 10th grade
# 5                                          0
# 6                                High school
# 7                              Never married
# 8                Not in universe or children
# 9                            Not in universe
# 10                 Asian or Pacific Islander
# 11                                 All other
# 12                                    Female
# 13                           Not in universe
# 14                           Not in universe
# 15                        Not in labor force
# 16                                         0
# 17                                         0
# 18                                         0
# 19                                  Nonfiler
# 20                           Not in universe
# 21                           Not in universe
# 22   Child 18+ never marr Not in a subfamily
# 23                         Child 18 or older
# 24                                         ?
# 25                                         ?
# 26                                         ?
# 27          Not in universe under 1 year old
# 28                                         ?
# 29                                         0
# 30                           Not in universe
# 31                                   Vietnam
# 32                                   Vietnam
# 33                                   Vietnam
# 34       Foreign born- Not a citizen of U S
# 35                                         0
# 36                           Not in universe
# 37                                         2
# 38                                         0
# 39                                        95
# 40                                    -50000

# %%
continuous_columns
# Out:
# [0, 5, 16, 17, 18, 29, 38]

# %% [markdown]
# ### 2. Create a TGAN instance
#
# The next step is to import TGAN and create an instance of the model.
#
# To do so, we need to import the `tgan.model.TGANModel` class and call it.
#
# This will create a TGAN instance with the default parameters.

# %%
from tgan.model import TGANModel

tgan = TGANModel(continuous_columns=continuous_columns)

# %% [markdown]
# ### 3. Fit the model
#
# The third step is to pass the data that we have loaded previously to the `TGANModel.fit` method to
# start the fitting.
#
# This process will not return anything, however, the progress of the fitting will be printed into screen.
#
# **NOTE** Depending on the performance of the system you are running, and the parameters selected
# for the model, this step can take up to a few hours.

# %%
tgan.fit(data)
# Out:
# W1028 18:26:30.685026 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/graph_builder/model_desc.py:29: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1028 18:26:30.686195 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/graph_builder/model_desc.py:39: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1028 18:26:30.713852 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/input_source/input_source.py:219: The name tf.FIFOQueue is deprecated. Please use tf.queue.FIFOQueue instead.
# [1028 18:26:30 @input_source.py:222] Setting up the queue 'QueueInput/input_queue' for CPU prefetching ...
# W1028 18:26:30.724647 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/summary.py:237: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W1028 18:26:30.725765 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/summary.py:27: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1028 18:26:30.726706 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/summary.py:254: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W1028 18:26:30.748533 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/summary.py:264: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1028 18:26:30.752035 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/collection.py:105: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W1028 18:26:30.753166 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/collection.py:33: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W1028 18:26:30.756622 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:455: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W1028 18:26:30.761121 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:458: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W1028 18:26:30.763019 139853287569216 deprecation.py:323] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:259: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W1028 18:26:30.790631 139853287569216 deprecation.py:323] From /home/ykene219/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W1028 18:26:30.799685 139853287569216 deprecation.py:506] From /home/ykene219/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [1028 18:26:30 @registry.py:126] gen/LSTM/00/FC input: [200, 100]
# W1028 18:26:30.817327 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/models/fc.py:57: The name tf.layers.Dense is deprecated. Please use tf.compat.v1.layers.Dense instead.
#
# W1028 18:26:30.818364 139853287569216 deprecation.py:323] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/models/fc.py:67: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# [1028 18:26:30 @registry.py:134] gen/LSTM/00/FC output: [200, 100]
# [1028 18:26:30 @registry.py:126] gen/LSTM/00/FC2 input: [200, 100]
# [1028 18:26:30 @registry.py:134] gen/LSTM/00/FC2 output: [200, 1]
# [1028 18:26:30 @registry.py:126] gen/LSTM/01/FC input: [200, 100]
# [1028 18:26:30 @registry.py:134] gen/LSTM/01/FC output: [200, 100]
# [1028 18:26:30 @registry.py:126] gen/LSTM/01/FC2 input: [200, 100]
# [1028 18:26:30 @registry.py:134] gen/LSTM/01/FC2 output: [200, 5]
# [1028 18:26:30 @registry.py:126] gen/LSTM/01/FC3 input: [200, 5]
# [1028 18:26:30 @registry.py:134] gen/LSTM/01/FC3 output: [200, 100]
# [1028 18:26:30 @registry.py:126] gen/LSTM/02/FC input: [200, 100]
# [1028 18:26:31 @registry.py:134] gen/LSTM/02/FC output: [200, 100]
# [1028 18:26:31 @registry.py:126] gen/LSTM/02/FC2 input: [200, 100]
# [1028 18:26:31 @registry.py:134] gen/LSTM
: [200, 100]
# [1028 18:26:35 @registry.py:126] gen/LSTM/46/FC input: [200, 100]
# [1028 18:26:35 @registry.py:134] gen/LSTM/46/FC output: [200, 100]
# [1028 18:26:35 @registry.py:126] gen/LSTM/46/FC2 input: [200, 100]
# [1028 18:26:35 @registry.py:134] gen/LSTM/46/FC2 output: [200, 2]
# [1028 18:26:35 @registry.py:126] gen/LSTM/46/FC3 input: [200, 2]
# [1028 18:26:35 @registry.py:134] gen/LSTM/46/FC3 output: [200, 100]
# [1028 18:26:35 @registry.py:126] gen/LSTM/47/FC input: [200, 100]
# [1028 18:26:35 @registry.py:134] gen/LSTM/47/FC output: [200, 100]
# [1028 18:26:35 @registry.py:126] gen/LSTM/47/FC2 input: [200, 100]
# [1028 18:26:35 @registry.py:134] gen/LSTM/47/FC2 output: [200, 2]
# [1028 18:26:35 @registry.py:126] gen/LSTM/47/FC3 input: [200, 2]
# [1028 18:26:35 @registry.py:134] gen/LSTM/47/FC3 output: [200, 100]
# W1028 18:26:35.694426 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:494: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1028 18:26:36.017484 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:443: The name tf.log is deprecated. Please use tf.math.log instead.
# [1028 18:26:36 @registry.py:126] discrim/dis_fc0/fc input: [200, 547]
# [1028 18:26:36 @registry.py:134] discrim/dis_fc0/fc output: [200, 100]
# [1028 18:26:36 @registry.py:126] discrim/dis_fc0/fc_diversity input: [200, 100]
# [1028 18:26:36 @registry.py:134] discrim/dis_fc0/fc_diversity output: [200, 100]
# W1028 18:26:36.532125 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/models/batch_norm.py:204: The name tf.layers.BatchNormalization is deprecated. Please use tf.compat.v1.layers.BatchNormalization instead.
#
# W1028 18:26:36.561906 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/models/batch_norm.py:212: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
# [1028 18:26:36 @registry.py:126] discrim/dis_fc_top input: [200, 110]
# [1028 18:26:36 @registry.py:134] discrim/dis_fc_top output: [200, 1]
# W1028 18:26:36.652279 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:118: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W1028 18:26:36.658316 139853287569216 deprecation.py:323] From /home/ykene219/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1028 18:26:36.685070 139853287569216 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W1028 18:26:37.947972 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tgan/model.py:551: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# [1028 18:26:51 @logger.py:83] Existing log file 'output/logs/log.log' backuped to 'output/logs/log.log.1028-182651'
# [1028 18:26:51 @logger.py:90] Argv: /u01/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py -f /home/ykene219/.local/share/jupyter/runtime/kernel-0da1038d-a013-46b6-b26c-363f25a1b34b.json
# W1028 18:26:51.818787 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/saver.py:43: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# W1028 18:26:51.819836 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/common.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1028 18:26:51 @model_utils.py:67] List of Trainable Variables:
# name                              shape         #elements
# --------------------------------  ----------  -----------
# gen/LSTM/go:0                     [1, 100]            100
# gen/LSTM/lstm_cell/kernel:0       [500, 400]       200000
# gen/LSTM/lstm_cell/bias:0         [400]               400
# gen/LSTM/00/FC/W:0                [100, 100]        10000
# gen/LSTM/00/FC/b:0                [100]               100
# gen/LSTM/00/FC2/W:0               [100, 1]            100
# gen/LSTM/00/FC2/b:0               [1]                   1
# gen/LSTM/00/attw:0                [1, 1, 1]             1
# gen/LSTM/01/FC/W:0                [100, 100]        10000
# gen/LSTM/01/FC/b:0                [100]               100
# gen/LSTM/01/FC2/W:0               [100, 5]            500
# gen/LSTM/01/FC2/b:0               [5]                   5
# gen/LSTM/01/FC3/W:0               [5, 100]            500
# gen/LSTM/01/FC3/b:0               [100]               100
# gen/LSTM/01/attw:0                [2, 1, 1]             2
# gen/LSTM/02/FC/W:0                [100, 100]        10000
# gen/LSTM/02/FC/b:0                [100]               100
# gen/LSTM/02/FC2/W:0               [100, 9]            900
# gen/LSTM/02/FC2/b:0               [9]                   9
# gen/LSTM/02/FC3/W:0               [9, 100]            900
# gen/LSTM/02/FC3/b:0               [100]               100
# gen/LSTM/02/attw:0                [3, 1, 1]             3
# gen/LSTM/03/FC/W:0                [100, 100]        10000
# gen/LSTM/03/FC/b:0                [100]               100
# gen/LSTM/03/FC2/W:0               [100, 52]          5200
# gen/LSTM/03/FC2/b:0               [52]                 52
# gen/LSTM/03/FC3/W:0               [52, 100]          5200
# gen/LSTM/03/FC3/b:0               [100]               100
# gen/LSTM/03/attw:0                [4, 1, 1]             4
# gen/LSTM/04/FC/W:0                [100, 100]        10000
# gen/LSTM/04/FC/b:0                [100]               100
# gen/LSTM/04/FC2/W:0               [100, 47]          4700
# gen/LSTM/04/FC2/b:0               [47]                 47
# gen/LSTM/04/FC3/W:0               [47, 100]          4700
# gen/LSTM/04/FC3/b:0               [100]               100
# gen/LSTM/04/attw:0                [5, 1, 1]             5
# gen/LSTM/05/FC/W:0                [100, 100]        10000
# gen/LSTM/05/FC/b:0                [100]               100
# gen/LSTM/05/FC2/W:0               [100, 17]          1700
# gen/LSTM/05/FC2/b:0               [17]                 17
# gen/LSTM/05/FC3/W:0               [17, 100]          1700
# gen/LSTM/05/FC3/b:0               [100]               100
# gen/LSTM/05/attw:0                [6, 1, 1]             6
# gen/LSTM/06/FC/W:0                [100, 100]        10000
# gen/LSTM/06/FC/b:0                [100]               100
# gen/LSTM/06/FC2/W:0               [100, 1]            100
# gen/LSTM/06/FC2/b:0               [1]                   1
# gen/LSTM/06/attw:0                [7, 1, 1]             7
# gen/LSTM/07/FC/W:0                [100, 100]        10000
# gen/LSTM/07/FC/b:0                [100]               100
# gen/LSTM/07/FC2/W:0               [100, 5]            500
# gen/LSTM/07/FC2/b:0               [5]                   5
# gen/LSTM/07/FC3/W:0               [5, 100]            500
# gen/LSTM/07/FC3/b:0               [100]               100
# gen/LSTM/07/attw:0                [8, 1, 1]             8
# gen/LSTM/08/FC/W:0                [100, 100]        10000
# gen/LSTM/08/FC/b:0                [100]               100
# gen/LSTM/08/FC2/W:0               [100, 3]            300
# gen/LSTM/08/FC2/b:0               [3]                   3
# gen/LSTM/08/FC3/W:0               [3, 100]            300
# gen/LSTM/08/FC3/b:0               [100]               100
# gen/LSTM/08/attw:0                [9, 1, 1]             9
# gen/LSTM/09/FC/W:0                [100, 100]        10000
# gen/LSTM/09/FC/b:0                [100]               100
# gen/LSTM/09/FC2/W:0               [100, 7]            700
# gen/LSTM/09/FC2/b:0               [7]                   7
# gen/LSTM/09/FC3/W:0               [7, 100]            700
# gen/LSTM/09/FC3/b:0               [100]               100
# gen/LSTM/09/attw:0                [10, 1, 1]           10
# gen/LSTM/10/FC/W:0                [100, 100]        10000
# gen/LSTM/10/FC/b:0                [100]               100
# gen/LSTM/10/FC2/W:0               [100, 24]          2400
# gen/LSTM/10/FC2/b:0               [24]                 24
# gen/LSTM/10/FC3/W:0               [24, 100]          2400
# gen/LSTM/10/FC3/b:0               [100]               100
# gen/LSTM/10/attw:0                [11, 1, 1]           11
# gen/LSTM/11/FC/W:0                [100, 100]        10000
# gen/LSTM/11/FC/b:0                [100]               100
# gen/LSTM/11/FC2/W:0               [100, 15]          1500
# gen/LSTM/11/FC2/b:0               [15]                 15
# gen/LSTM/11/FC3/W:0               [15, 100]          1500
# gen/LSTM/11/FC3/b:0               [100]               100
# gen/LSTM/11/attw:0                [12, 1, 1]           12
# gen/LSTM/12/FC/W:0                [100, 100]        10000
# gen/LSTM/12/FC/b:0                [100]               100
# gen/LSTM/12/FC2/W:0               [100, 5]            500
# gen/LSTM/12/FC2/b:0               [5]                   5
# gen/LSTM/12/FC3/W:0               [5, 100]            500
# gen/LSTM/12/FC3/b:0               [100]               100
# gen/LSTM/12/attw:0                [13, 1, 1]           13
# gen/LSTM/13/FC/W:0                [100, 100]        10000
# gen/LSTM/13/FC/b:0                [100]               100
# gen/LSTM/13/FC2/W:0               [100, 10]          1000
# gen/LSTM/13/FC2/b:0               [10]                 10
# gen/LSTM/13/FC3/W:0               [10, 100]          1000
# gen/LSTM/13/FC3/b:0               [100]               100
# gen/LSTM/13/attw:0                [14, 1, 1]           14
# gen/LSTM/14/FC/W:0                [100, 100]        10000
# gen/LSTM/14/FC/b:0                [100]               100
# gen/LSTM/14/FC2/W:0               [100, 2]            200
# gen/LSTM/14/FC2/b:0               [2]                   2
# gen/LSTM/14/FC3/W:0               [2, 100]            200
# gen/LSTM/14/FC3/b:0               [100]               100
# gen/LSTM/14/attw:0                [15, 1, 1]           15
# gen/LSTM/15/FC/W:0                [100, 100]        10000
# gen/LSTM/15/FC/b:0                [100]               100
# gen/LSTM/15/FC2/W:0               [100, 3]            300
# gen/LSTM/15/FC2/b:0               [3]                   3
# gen/LSTM/15/FC3/W:0               [3, 100]            300
# gen/LSTM/15/FC3/b:0               [100]               100
# gen/LSTM/15/attw:0                [16, 1, 1]           16
# gen/LSTM/16/FC/W:0                [100, 100]        10000
# gen/LSTM/16/FC/b:0                [100]               100
# gen/LSTM/16/FC2/W:0               [100, 6]            600
# gen/LSTM/16/FC2/b:0               [6]                   6
# gen/LSTM/16/FC3/W:0               [6, 100]            600
# gen/LSTM/16/FC3/b:0               [100]               100
# gen/LSTM/16/attw:0                [17, 1, 1]           17
# gen/LSTM/17/FC/W:0                [100, 100]        10000
# gen/LSTM/17/FC/b:0                [100]               100
# gen/LSTM/17/FC2/W:0               [100, 8]            800
# gen/LSTM/17/FC2/b:0               [8]                   8
# gen/LSTM/17/FC3/W:0               [8, 100]            800
# gen/LSTM/17/FC3/b:0               [100]               100
# gen/LSTM/17/attw:0                [18, 1, 1]           18
# gen/LSTM/18/FC/W:0                [100, 100]        10000
# gen/LSTM/18/FC/b:0                [100]               100
# gen/LSTM/18/FC2/W:0               [100, 1]            100
# gen/LSTM/18/FC2/b:0               [1]                   1
# gen/LSTM/18/attw:0                [19, 1, 1]           19
# gen/LSTM/19/FC/W:0                [100, 100]        10000
# gen/LSTM/19/FC/b:0                [100]               100
# gen/LSTM/19/FC2/W:0               [100, 5]            500
# gen/LSTM/19/FC2/b:0               [5]                   5
# gen/LSTM/19/FC3/W:0               [5, 100]            500
# gen/LSTM/19/FC3/b:0               [100]               100
# gen/LSTM/19/attw:0                [20, 1, 1]           20
# gen/LSTM/20/FC/W:0                [100, 100]        10000
# gen/LSTM/20/FC/b:0                [100]               100
# gen/LSTM/20/FC2/W:0               [100, 1]            100
# gen/LSTM/20/FC2/b:0               [1]                   1
# gen/LSTM/20/attw:0                [21, 1, 1]           21
# gen/LSTM/21/FC/W:0                [100, 100]        10000
# gen/LSTM/21/FC/b:0                [100]               100
# gen/LSTM/21/FC2/W:0               [100, 5]            500
# gen/LSTM/21/FC2/b:0               [5]                   5
# gen/LSTM/21/FC3/W:0               [5, 100]            500
# gen/LSTM/21/FC3/b:0               [100]               100
# gen/LSTM/21/attw:0                [22, 1, 1]           22
# gen/LSTM/22/FC/W:0                [100, 100]        10000
# gen/LSTM/22/FC/b:0                [100]               100
# gen/LSTM/22/FC2/W:0               [100, 1]            100
# gen/LSTM/22/FC2/b:0               [1]                   1
# gen/LSTM/22/attw:0                [23, 1, 1]           23
# gen/LSTM/23/FC/W:0                [100, 100]        10000
# gen/LSTM/23/FC/b:0                [100]               100
# gen/LSTM/23/FC2/W:0               [100, 5]            500
# gen/LSTM/23/FC2/b:0               [5]                   5
# gen/LSTM/23/FC3/W:0               [5, 100]            500
# gen/LSTM/23/FC3/b:0               [100]               100
# gen/LSTM/23/attw:0                [24, 1, 1]           24
# gen/LSTM/24/FC/W:0                [100, 100]        10000
# gen/LSTM/24/FC/b:0                [100]               100
# gen/LSTM/24/FC2/W:0               [100, 6]            600
# gen/LSTM/24/FC2/b:0               [6]                   6
# gen/LSTM/24/FC3/W:0               [6, 100]            600
# gen/LSTM/24/FC3/b:0               [100]               100
# gen/LSTM/24/attw:0                [25, 1, 1]           25
# gen/LSTM/25/FC/W:0                [100, 100]        10000
# gen/LSTM/25/FC/b:0                [100]               100
# gen/LSTM/25/FC2/W:0               [100, 6]            600
# gen/LSTM/25/FC2/b:0               [6]                   6
# gen/LSTM/25/FC3/W:0               [6, 100]            600
# gen/LSTM/25/FC3/b:0               [100]               100
# gen/LSTM/25/attw:0                [26, 1, 1]           26
# gen/LSTM/26/FC/W:0                [100, 100]        10000
# gen/LSTM/26/FC/b:0                [100]               100
# gen/LSTM/26/FC2/W:0               [100, 51]          5100
# gen/LSTM/26/FC2/b:0               [51]                 51
# gen/LSTM/26/FC3/W:0               [51, 100]          5100
# gen/LSTM/26/FC3/b:0               [100]               100
# gen/LSTM/26/attw:0                [27, 1, 1]           27
# gen/LSTM/27/FC/W:0                [100, 100]        10000
# gen/LSTM/27/FC/b:0                [100]               100
# gen/LSTM/27/FC2/W:0               [100, 38]          3800
# gen/LSTM/27/FC2/b:0               [38]                 38
# gen/LSTM/27/FC3/W:0               [38, 100]          3800
# gen/LSTM/27/FC3/b:0               [100]               100
# gen/LSTM/27/attw:0                [28, 1, 1]           28
# gen/LSTM/28/FC/W:0                [100, 100]        10000
# gen/LSTM/28/FC/b:0                [100]               100
# gen/LSTM/28/FC2/W:0               [100, 8]            800
# gen/LSTM/28/FC2/b:0               [8]                   8
# gen/LSTM/28/FC3/W:0               [8, 100]            800
# gen/LSTM/28/FC3/b:0               [100]               100
# gen/LSTM/28/attw:0                [29, 1, 1]           29
# gen/LSTM/29/FC/W:0                [100, 100]        10000
# gen/LSTM/29/FC/b:0                [100]               100
# gen/LSTM/29/FC2/W:0               [100, 10]          1000
# gen/LSTM/29/FC2/b:0               [10]                 10
# gen/LSTM/29/FC3/W:0               [10, 100]          1000
# gen/LSTM/29/FC3/b:0               [100]               100
# gen/LSTM/29/attw:0                [30, 1, 1]           30
# gen/LSTM/30/FC/W:0                [100, 100]        10000
# gen/LSTM/30/FC/b:0                [100]               100
# gen/LSTM/30/FC2/W:0               [100, 9]            900
# gen/LSTM/30/FC2/b:0               [9]                   9
# gen/LSTM/30/FC3/W:0               [9, 100]            900
# gen/LSTM/30/FC3/b:0               [100]               100
# gen/LSTM/30/attw:0                [31, 1, 1]           31
# gen/LSTM/31/FC/W:0                [100, 100]        10000
# gen/LSTM/31/FC/b:0                [100]               100
# gen/LSTM/31/FC2/W:0               [100, 10]          1000
# gen/LSTM/31/FC2/b:0               [10]                 10
# gen/LSTM/31/FC3/W:0               [10, 100]          1000
# gen/LSTM/31/FC3/b:0               [100]               100
# gen/LSTM/31/attw:0                [32, 1, 1]           32
# gen/LSTM/32/FC/W:0                [100, 100]        10000
# gen/LSTM/32/FC/b:0                [100]               100
# gen/LSTM/32/FC2/W:0               [100, 3]            300
# gen/LSTM/32/FC2/b:0               [3]                   3
# gen/LSTM/32/FC3/W:0               [3, 100]            300
# gen/LSTM/32/FC3/b:0               [100]               100
# gen/LSTM/32/attw:0                [33, 1, 1]           33
# gen/LSTM/33/FC/W:0                [100, 100]        10000
# gen/LSTM/33/FC/b:0                [100]               100
# gen/LSTM/33/FC2/W:0               [100, 4]            400
# gen/LSTM/33/FC2/b:0               [4]                   4
# gen/LSTM/33/FC3/W:0               [4, 100]            400
# gen/LSTM/33/FC3/b:0               [100]               100
# gen/LSTM/33/attw:0                [34, 1, 1]           34
# gen/LSTM/34/FC/W:0                [100, 100]        10000
# gen/LSTM/34/FC/b:0                [100]               100
# gen/LSTM/34/FC2/W:0               [100, 1]            100
# gen/LSTM/34/FC2/b:0               [1]                   1
# gen/LSTM/34/attw:0                [35, 1, 1]           35
# gen/LSTM/35/FC/W:0                [100, 100]        10000
# gen/LSTM/35/FC/b:0                [100]               100
# gen/LSTM/35/FC2/W:0               [100, 5]            500
# gen/LSTM/35/FC2/b:0               [5]                   5
# gen/LSTM/35/FC3/W:0               [5, 100]            500
# gen/LSTM/35/FC3/b:0               [100]               100
# gen/LSTM/35/attw:0                [36, 1, 1]           36
# gen/LSTM/36/FC/W:0                [100, 100]        10000
# gen/LSTM/36/FC/b:0                [100]               100
# gen/LSTM/36/FC2/W:0               [100, 5]            500
# gen/LSTM/36/FC2/b:0               [5]                   5
# gen/LSTM/36/FC3/W:0               [5, 100]            500
# gen/LSTM/36/FC3/b:0               [100]               100
# gen/LSTM/36/attw:0                [37, 1, 1]           37
# gen/LSTM/37/FC/W:0                [100, 100]        10000
# gen/LSTM/37/FC/b:0                [100]               100
# gen/LSTM/37/FC2/W:0               [100, 43]          4300
# gen/LSTM/37/FC2/b:0               [43]                 43
# gen/LSTM/37/FC3/W:0               [43, 100]          4300
# gen/LSTM/37/FC3/b:0               [100]               100
# gen/LSTM/37/attw:0                [38, 1, 1]           38
# gen/LSTM/38/FC/W:0                [100, 100]        10000
# gen/LSTM/38/FC/b:0                [100]               100
# gen/LSTM/38/FC2/W:0               [100, 43]          4300
# gen/LSTM/38/FC2/b:0               [43]                 43
# gen/LSTM/38/FC3/W:0               [43, 100]          4300
# gen/LSTM/38/FC3/b:0               [100]               100
# gen/LSTM/38/attw:0                [39, 1, 1]           39
# gen/LSTM/39/FC/W:0                [100, 100]        10000
# gen/LSTM/39/FC/b:0                [100]               100
# gen/LSTM/39/FC2/W:0               [100, 43]          4300
# gen/LSTM/39/FC2/b:0               [43]                 43
# gen/LSTM/39/FC3/W:0               [43, 100]          4300
# gen/LSTM/39/FC3/b:0               [100]               100
# gen/LSTM/39/attw:0                [40, 1, 1]           40
# gen/LSTM/40/FC/W:0                [100, 100]        10000
# gen/LSTM/40/FC/b:0                [100]               100
# gen/LSTM/40/FC2/W:0               [100, 5]            500
# gen/LSTM/40/FC2/b:0               [5]                   5
# gen/LSTM/40/FC3/W:0               [5, 100]            500
# gen/LSTM/40/FC3/b:0               [100]               100
# gen/LSTM/40/attw:0                [41, 1, 1]           41
# gen/LSTM/41/FC/W:0                [100, 100]        10000
# gen/LSTM/41/FC/b:0                [100]               100
# gen/LSTM/41/FC2/W:0               [100, 3]            300
# gen/LSTM/41/FC2/b:0               [3]                   3
# gen/LSTM/41/FC3/W:0               [3, 100]            300
# gen/LSTM/41/FC3/b:0               [100]               100
# gen/LSTM/41/attw:0                [42, 1, 1]           42
# gen/LSTM/42/FC/W:0                [100, 100]        10000
# gen/LSTM/42/FC/b:0                [100]               100
# gen/LSTM/42/FC2/W:0               [100, 3]            300
# gen/LSTM/42/FC2/b:0               [3]                   3
# gen/LSTM/42/FC3/W:0               [3, 100]            300
# gen/LSTM/42/FC3/b:0               [100]               100
# gen/LSTM/42/attw:0                [43, 1, 1]           43
# gen/LSTM/43/FC/W:0                [100, 100]        10000
# gen/LSTM/43/FC/b:0                [100]               100
# gen/LSTM/43/FC2/W:0               [100, 3]            300
# gen/LSTM/43/FC2/b:0               [3]                   3
# gen/LSTM/43/FC3/W:0               [3, 100]            300
# gen/LSTM/43/FC3/b:0               [100]               100
# gen/LSTM/43/attw:0                [44, 1, 1]           44
# gen/LSTM/44/FC/W:0                [100, 100]        10000
# gen/LSTM/44/FC/b:0                [100]               100
# gen/LSTM/44/FC2/W:0               [100, 1]            100
# gen/LSTM/44/FC2/b:0               [1]                   1
# gen/LSTM/44/attw:0                [45, 1, 1]           45
# gen/LSTM/45/FC/W:0                [100, 100]        10000
# gen/LSTM/45/FC/b:0                [100]               100
# gen/LSTM/45/FC2/W:0               [100, 5]            500
# gen/LSTM/45/FC2/b:0               [5]                   5
# gen/LSTM/45/FC3/W:0               [5, 100]            500
# gen/LSTM/45/FC3/b:0               [100]               100
# gen/LSTM/45/attw:0                [46, 1, 1]           46
# gen/LSTM/46/FC/W:0                [100, 100]        10000
# gen/LSTM/46/FC/b:0                [100]               100
# gen/LSTM/46/FC2/W:0               [100, 2]            200
# gen/LSTM/46/FC2/b:0               [2]                   2
# gen/LSTM/46/FC3/W:0               [2, 100]            200
# gen/LSTM/46/FC3/b:0               [100]               100
# gen/LSTM/46/attw:0                [47, 1, 1]           47
# gen/LSTM/47/FC/W:0                [100, 100]        10000
# gen/LSTM/47/FC/b:0                [100]               100
# gen/LSTM/47/FC2/W:0               [100, 2]            200
# gen/LSTM/47/FC2/b:0               [2]                   2
# gen/LSTM/47/FC3/W:0               [2, 100]            200
# gen/LSTM/47/FC3/b:0               [100]               100
# gen/LSTM/47/attw:0                [48, 1, 1]           48
# discrim/dis_fc0/fc/W:0            [547, 100]        54700
# discrim/dis_fc0/fc/b:0            [100]               100
# discrim/dis_fc0/fc_diversity/W:0  [100, 100]        10000
# discrim/dis_fc0/fc_diversity/b:0  [100]               100
# discrim/dis_fc0/bn/beta:0         [110]               110
# discrim/dis_fc_top/W:0            [110, 1]            110
# discrim/dis_fc_top/b:0            [1]                   1
# Number of trainable variables: 332
# Number of parameters (elements): 864944
# Storage space needed for all trainable variables: 3.30MB
# [1028 18:26:51 @base.py:209] Setup callbacks graph ...
# W1028 18:26:51.866577 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/graph.py:54: The name tf.train.SessionRunArgs is deprecated. Please use tf.estimator.SessionRunArgs instead.
#
# W1028 18:26:51.867512 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/common.py:75: The name tf.VariableScope is deprecated. Please use tf.compat.v1.VariableScope instead.
#
# W1028 18:26:51.868549 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/common.py:77: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# W1028 18:26:51.874365 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/steps.py:117: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1028 18:26:51.877150 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/saver.py:55: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1028 18:26:51.877763 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/saver.py:59: The name tf.train.SaverDef is deprecated. Please use tf.compat.v1.train.SaverDef instead.
# [1028 18:26:52 @summary.py:46] [MovingAverageSummary] 6 operations in collection 'MOVING_SUMMARY_OPS' will be run with session hooks.
# [1028 18:26:52 @summary.py:93] Summarizing collection 'summaries' of size 9.
# W1028 18:26:52.749906 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/summary.py:94: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# [1028 18:26:52 @graph.py:98] Applying collection UPDATE_OPS of 4 ops.
# W1028 18:26:52.754289 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/monitor.py:261: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# [1028 18:26:57 @base.py:230] Creating the session ...
# W1028 18:26:57.060172 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:42: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1028 18:26:59.409047 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:71: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# W1028 18:26:59.427433 139853287569216 deprecation.py:323] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# W1028 18:27:03.748813 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:72: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# W1028 18:27:05.588243 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/sesscreate.py:73: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# W1028 18:27:07.460619 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/train/base.py:254: The name tf.train.MonitoredSession is deprecated. Please use tf.compat.v1.train.MonitoredSession instead.
# [1028 18:27:07 @base.py:236] Initializing the session ...
# [1028 18:27:07 @base.py:243] Graph Finalized.
# W1028 18:27:07.463223 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/common.py:89: The name tf.train.global_step is deprecated. Please use tf.compat.v1.train.global_step instead.
#
# W1028 18:27:07.463958 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/tfutils/common.py:90: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# [1028 18:27:08 @concurrency.py:38] Starting EnqueueThread QueueInput/input_queue ...
# W1028 18:27:11.078432 139853287569216 module_wrapper.py:139] From /home/ykene219/.local/lib/python3.6/site-packages/tensorpack/callbacks/monitor.py:309: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# [1028 18:27:11 @base.py:275] Start Epoch 1 ...
#   0%|          |23/10000[00:23<1:06:51, 2.49it/s]
# [1028 18:27:34 @base.py:293] Detected Ctrl-C and exiting main loop.
# [1028 18:27:35 @input_source.py:178] EnqueueThread QueueInput/input_queue Exited.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f27a8b3f518c> in <module>()
# ----> 1 tgan.fit(data)
#
# ~/.local/lib/python3.6/site-packages/tgan/model.py in fit(self, data)
#     714             max_epoch=self.max_epoch,
#     715             session_init=session_init,
# --> 716             starting_epoch=starting_epoch
#     717         )
#     718
#
# ~/.local/lib/python3.6/site-packages/tensorpack/train/base.py in train_with_defaults(self, _sentinel, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch, extra_callbacks)
#     342         self.train(callbacks, monitors,
#     343                    session_creator, session_init,
# --> 344                    steps_per_epoch, starting_epoch, max_epoch)
#     345
#     346     def __new__(cls, *args, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/tensorpack/train/base.py in train(self, callbacks, monitors, session_creator, session_init, steps_per_epoch, starting_epoch, max_epoch)
#     314         self.setup_callbacks(callbacks, monitors)
#     315         self.initialize(session_creator, session_init)
# --> 316         self.main_loop(steps_per_epoch, starting_epoch, max_epoch)
#     317
#     318     def train_with_defaults(
#
# ~/.local/lib/python3.6/site-packages/tensorpack/utils/argtools.py in wrapper(*args, **kwargs)
#     174         cache.add(func)
#     175
# --> 176         return func(*args, **kwargs)
#     177
#     178     return wrapper
#
# ~/.local/lib/python3.6/site-packages/tensorpack/train/base.py in main_loop(self, steps_per_epoch, starting_epoch, max_epoch)
#     279                         if self.hooked_sess.should_stop():
#     280                             return
# --> 281                         self.run_step()  # implemented by subclass
#     282                         self._callbacks.trigger_step()
#     283                     self._callbacks.after_epoch()
#
# ~/.local/lib/python3.6/site-packages/tensorpack/train/base.py in run_step(self)
#     179                 "Please either set `Trainer.train_op` or provide an implementation "
#     180                 "of Trainer.run_step()!")
# --> 181         self.hooked_sess.run(self.train_op)
#     182
#     183     @call_only_once
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1257             feed_dict=feed_dict,
#    1258             options=options,
# -> 1259             run_metadata=run_metadata)
#    1260       except _PREEMPTION_ERRORS as e:
#    1261         logging.info(
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1343   def run(self, *args, **kwargs):
#    1344     try:
# -> 1345       return self._sess.run(*args, **kwargs)
#    1346     except _PREEMPTION_ERRORS:
#    1347       raise
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1416         feed_dict=feed_dict,
#    1417         options=options,
# -> 1418         run_metadata=run_metadata)
#    1419
#    1420     for hook in self._hooks:
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1174
#    1175   def run(self, *args, **kwargs):
# -> 1176     return self._sess.run(*args, **kwargs)
#    1177
#    1178   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4. Sample new data
#
# After the model has been fit, we are ready to generate new samples by calling the `TGANModel.sample`
# method passing it the desired amount of samples.
#
# The returned object, `samples`, is a `pandas.DataFrame` containing a table of synthetic data with
# the same format as the input data and 1000 rows as we requested.

# %%
num_samples = 1000

samples = tgan.sample(num_samples)

samples.head(3)

# %% [markdown]
# ### 5. Save and Load a model
#
# In the steps above we saw that the fitting process is slow, so we probably would like to avoid having to fit every we want to generate samples. Instead we can fit a model once, save it, and load it every time we want to sample new data.
#
# If we have a fitted model, we can save it by calling the `TGANModel.save` method, that only takes
# as argument the path to store the model into. Similarly, the `TGANModel.load` allows to load a model stored on disk by passing as argument a path where the model is stored.
#
# At this point we could use this model instance to generate more samples.

# %%
model_path = 'demo/my_model'

tgan.save(model_path)

# %%
new_tgan = TGANModel.load(model_path)

# %%
new_samples = new_tgan.sample(num_samples)

new_samples.head(3)

# %% [markdown]
# ## Loading custom datasets
#
# In the previous steps we used some demonstration data but we did not show how to load your own dataset.
#
# In order to do so you can use `pandas.read_csv` by passing it the path to the CSV file that you want to load.
#
# Additionally, you will need to create 0-indexed list of columns indices to be considered continuous.
#
# For example, if we want to load a local CSV file, `path/to/my.csv`, that has as continuous columns their first 4 columns, that is, indices `[0,1,2,3]`, we would do it like this:

# %%
import pandas as pd

data = pd.read_csv('data/census.csv')

continuous_columns = [0,1,2,3]

# %% [markdown]
# ## Model Parameters
#
# If you want to change the default behavior of TGANModel, such as as different `batch_size` or
# `num_epochs`, you can do so by passing different arguments when creating the instance. Have b
#
# ### Model general behavior
#
# * continous_columns (`list[int]`, required): List of columns to be considered continuous.
# * output (`str`, default=`output`): Path to store the model and its artifacts.
# * gpu (`list[str]`, default=`[]`): Comma separated list of GPU(s) to use.
#
# ### Neural network definition and fitting
#
# * max_epoch (`int`, default=`100`): Number of epochs to use during training.
# * steps_per_epoch (`int`, default=`10000`): Number of steps to run on each epoch.
# * save_checkpoints(`bool`, default=True): Whether or not to store checkpoints of the model after each training epoch.
# * restore_session(`bool`, default=True): Whether or not continue training from the last checkpoint.
# * batch_size (`int`, default=`200`): Size of the batch to feed the model at each step.
# * z_dim (`int`, default=`100`): Number of dimensions in the noise input for the generator.
# * noise (`float`, default=`0.2`): Upper bound to the gaussian noise added to categorical columns.
# * l2norm (`float`, default=`0.00001`): L2 reguralization coefficient when computing losses.
# * learning_rate (`float`, default=`0.001`): Learning rate for the optimizer.
# * num_gen_rnn (`int`, default=`400`):
# * num_gen_feature (`int`, default=`100`): Number of features of in the generator.
# * num_dis_layers (`int`, default=`2`):
# * num_dis_hidden (`int`, default=`200`):
# * optimizer (`str`, default=`AdamOptimizer`): Name of the optimizer to use during `fit`, possible
#   values are: [`GradientDescentOptimizer`, `AdamOptimizer`, `AdadeltaOptimizer`].
#
# If we wanted to create an identical instance to the one created on step 2, but passing the arguments in a explicit way we will do something like this:

# %%
tgan = TGANModel(
    continuous_columns,
    output='output',
    gpu=None,
    max_epoch=5,
    steps_per_epoch=10000,
    save_checkpoints=True,
    restore_session=True,
    batch_size=200,
    z_dim=200,
    noise=0.2,
    l2norm=0.00001,
    learning_rate=0.001,
    num_gen_rnn=100,
    num_gen_feature=100,
    num_dis_layers=1,
    num_dis_hidden=100,
    optimizer='AdamOptimizer'
)

# %% [markdown]
# ## Command-line interface
#
# We include a command-line interface that allows users to access TGAN functionality. Currently only one action is supported.
#
# ### Random hyperparameter search
#
# #### Input
#
# To run random searchs for the best model hyperparameters for a given dataset, we will need:
#
# * A dataset, in a csv file, without any missing value, only columns of type `bool`, `str`, `int` or
#   `float` and only one type for column, as specified in [Data Format Input](#data-format-input).
#
# * A JSON file containing the configuration for the search. This configuration shall contain:
#
#   * `name`: Name of the experiment. A folder with this name will be created.
#   * `num_random_search`: Number of iterations in hyper parameter search.
#   * `train_csv`: Path to the csv file containing the dataset.
#   * `continuous_cols`: List of column indices, starting at 0, to be considered continuous.
#   * `epoch`: Number of epoches to train the model.
#   * `steps_per_epoch`: Number of optimization steps in each epoch.
#   * `sample_rows`: Number of rows to sample when evaluating the model.
#
# You can see an example of such a json file in [examples/config.json](examples/config.json), which you
# can download and use as a template.
#
# #### Execution
#
# Once we have prepared everything we can launch the random hyperparameter search with this command:
#
# ``` bash
# tgan experiments config.json results.json
# ```
#
# Where the first argument, `config.json`,  is the path to your configuration JSON, and the second,
# `results.json`, is the path to store the summary of the execution.
#
# This will run the random search, wich basically consist of the folling steps:
#
# 1. We fetch and split our data between test and train.
# 2. We randomly select the hyperparameters to test.
# 3. Then, for each hyperparameter combination, we train a TGAN model using the real training data T
#    and generate a synthetic training dataset Tsynth.
# 4. We then train machine learning models on both the real and synthetic datasets.
# 5. We use these trained models on real test data and see how well they perform.
#
# #### Output
#
# One the experiment has finished, the following can be found:
#
# * A JSON file, in the example above called `results.json`, containing a summary of the experiments.
#   This JSON will contain a key for each experiment `name`, and on it, an array of length
#   `num_random_search`, with the selected parameters and its evaluation score. For a configuration
#   like the example, the summary will look like this:
#
# ``` python
# {
#     'census': [
#         {
#             "steps_per_epoch" : 10000,
#             "num_gen_feature" : 300,
#             "num_dis_hidden" : 300,
#             "batch_size" : 100,
#             "num_gen_rnn" : 400,
#             "score" : 0.937802280415988,
#             "max_epoch" : 5,
#             "num_dis_layers" : 4,
#             "learning_rate" : 0.0002,
#             "z_dim" : 100,
#             "noise" : 0.2
#         },
#         ... # 9 more nodes
#     ]
# }
# ```
#
# * A set of folders, each one names after the `name` specified in the JSON configuration, contained
# in the `experiments` folder. In each folder, sampled data and the models can be found. For a configuration
# like the example, this will look like this:
#
# ```
# experiments/
#   census/
#     data/       # Sampled data with each of the models in the random search.
#     model_0/
#       logs/     # Training logs
#       model/    # Tensorflow model checkpoints
#     model_1/    # 9 more folders, one for each model in the random search
#     ...
# ```

# %% [markdown]
# ## Citation
#
# If you use TGAN, please cite the following work:
#
# > Lei Xu, Kalyan Veeramachaneni. 2018. Synthesizing Tabular Data using Generative Adversarial Networks.
#
# ```LaTeX
# @article{xu2018synthesizing,
#   title={Synthesizing Tabular Data using Generative Adversarial Networks},
#   author={Xu, Lei and Veeramachaneni, Kalyan},
#   journal={arXiv preprint arXiv:1811.11264},
#   year={2018}
# }
# ```
# You can find the original paper [here](https://arxiv.org/pdf/1811.11264.pdf)
